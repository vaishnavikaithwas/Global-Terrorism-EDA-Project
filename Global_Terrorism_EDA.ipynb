# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavikaithwas/Global-Terrorism-EDA-Project/blob/main/Global_Terrorism_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Global Terrorism EDA

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name -** Vaishnavi Kaithwas

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Global Terrorism Dataset (GTD) Project is a comprehensive collection of information on both domestic and international terrorist attacks occuring globally from 1970 through 2017.GTD Project serves as a vital resource in the field of terrorism studies. It enhances our understanding of terrorism as a global phenomenon and supports efforts to counter and prevent acts of terrorism worldwide.
#
#  GTD project  provides insights into the identity of the perpetrators behind terrorist attacks. While some incidents are carried out by known terrorist organizations.This project reveals valuable information about various aspects of terrorism, including the geographic distribution of attacks, target types, attack methods, and other useful insights. This information helps in identifying trends and hotspots of terrorist activities, assessing the effectiveness of counter terrorism efforts, and developing evidence-based strategies to combat terrorism.
#
# The analysis reveals that terrorism continues to be a significant global challenge. The frequency of terrorist attacks has shown a gradual decline in recent years, indicating some success in counter-terrorism efforts.The GTD allows us to categorize terrorist attacks based on their nature. Over the analyzed period, bombings and armed assaults have been the most common attack types.it gives detailed examination of terrorism trends in different regions.
#
# This Project serves as a vital resource in the field of terrorism studies. It enhances our understanding of terrorism as a global phenomenon and supports efforts to counter and prevent acts of terrorism worldwide ,by providing comprehensive and reliable data.The GTD analysis sheds light on the effectiveness of counter-terrorism measures.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/vaishnavikaithwas/Global-Terrorism-EDA-Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The **Global Terrorism Dataset (GTD)** analysis aims to identify global hot zones of terrorism and analyze evolving patterns in terrorist activities using data from the Global Terrorism Database (GTD). Terrorism involves violent acts that create fear. By examining GTD data, we aim to pinpoint the areas most affected by terrorism and understand how these patterns are changing over time. This analysis will provide insights into security issues, which can inform effective counter-terrorism strategies.

# %% [markdown]
# ## **Define Your Business Objective?**

# %% [markdown]
# The business objective of conducting an analysis on the **Global Terrorism Dataset (GTD)** is to provide valuable insights and actionable intelligence to various stakeholders, including governments, international organizations, security agencies, and policymakers. The primary goal is to enhance their understanding of global terrorism trends and patterns, enabling them to develop more effective strategies to combat terrorism and promote global security.
#
# Specifically, the objectives of the GTD analysis are as follows:
#
# **Identify Trends and Patterns:**
#
#  By analyzing the GTD, the objective is to uncover and understand the evolving trends in terrorist activities, including the types of attacks, geographic hotspots, and the changing dynamics of terrorism. This analysis will help stakeholders identify emerging threats, assess their severity, and allocate resources accordingly.
#
# **Inform Policy and Decision Making:**
#
#  The analysis aims to provide policymakers and decision-makers with evidence-based insights to support the formulation of effective counter-terrorism policies and initiatives. By understanding the underlying factors and motivations behind terrorism, stakeholders can develop targeted strategies to prevent radicalization, disrupt terrorist networks, and address root causes.
#
# **Enhance Security Measures:**
#
#  The analysis of the GTD will contribute to enhancing security measures by identifying vulnerabilities, areas of high risk, and potential targets. This information can be used to strengthen security protocols, improve intelligence sharing, and allocate resources more efficiently to prevent and respond to terrorist threats.
#
# **Evaluate Counter-terrorism Efforts:**
#
#  The business objective includes evaluating the effectiveness of current counter-terrorism efforts and identifying areas for improvement. By analyzing the outcomes of past strategies, stakeholders can learn from successes and failures, adapt their approaches, and ensure a more proactive and comprehensive response to terrorism.
#
# **Foster Collaboration:**
#
#  The GTD analysis aims to facilitate collaboration and information sharing among stakeholders. By providing a comprehensive understanding of global terrorism, it encourages international cooperation in combating terrorism, intelligence sharing, and coordinated efforts to address transnational terrorist networks.
#
# Overall, the business objective of the GTD analysis is to leverage the dataset to provide valuable insights that empower stakeholders to make informed decisions, enhance security measures, and work towards mitigating the global threat of terrorism.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load datset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Global Terrorism Data.csv",encoding = ('ISO-8859-1') )
# Out:
# <ipython-input-5-441a00cc7fe8>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Global Terrorism Data.csv",encoding = ('ISO-8859-1') )

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

data.shape
# Out:
# (181691, 135)

# %%
# checking dataset number of rows and columns using shape

print('Number of rows are:',data.shape[0])
print('Number of columns are:', data.shape[1])
# Out:
# Number of rows are: 181691
# Number of columns are: 135

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

duplicate_value_count = data.duplicated().sum()
duplicate_value_count
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

Null_Values_Count = data.isnull().sum()
Null_Values_Count
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Visualizing the Missing/Null values
# plotting the heat map for Missing/Null values

plt.figure(figsize = (20,10))
sns.heatmap(data.isnull(), cmap='YlOrRd', cbar=True)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This Dataset belongs to **Global Terrorism Database (GTD)** ,dataset contain 35 rows and 181690 columns (memory usage: 187.1+ MB) and we have to analyze the cause and different insight that the dataset carried.
#
# The GTD contains detailed data on various aspects of terrorist incidents, including the date, location, nature of the attack, target type, perpetrators, casualties, and other relevant information. It covers a wide range of terrorist activities and includes both domestic and international incidents.
#
# >
#
#
#
# >

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Dataset Describe

data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **eventid** : Unique ID for each  terrorist attack/incident/event.
#
# **iyear** : Year in which incident occured.
#
# **imonth** : Month in which incident occured.
#
# **iday** : Day in which incident occured.
#
# **approxdate** : Attack approximate date
#
# **country** : This field identifies the country code
#
# **country_txt** : The country or location  where the attack was carried
#                  out.
#
# **region** : This field identifies the region code based on 12 regions
#
# **region_txt** :The region in which the incident
#                 occurred.
#
# **city** : city in which incident occured
#
# **latitude** : latitude of attack location
#
# **longitude** : longitude of attack location
#
# **location** : Area of attacked zone
#
# **summary** : Full report about attack
#
# **crit1** : Condition critical level-1
#
# **crit2** : Condition critical level-2
#
# **crit3** : Condition critical level-3
#
# **success** : Success of a terrorist strike
#
# **suicide** : 1 = "Yes" The incident was a suicide attack. 0 = "No"
#               There is no indication that the incident was a suicide
#
# **attacktype1** : The general method of attack
#
# **target1** : The specific person, building that was targeted
#
# **natlty1_txt** : The nationality of the target that was attacked
#
# **gname** : The name of the group that carried out the attack
#
# **weaptype1_txt** : General type of weapon used in the incident
#
# **weapsubtype1_txt** : More specific value for most of the Weapon Types

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_year = data['iyear'].unique()
print(unique_year )

# this will leave a gap
print()

unique_country_txt = data['country_txt'].unique()
print(unique_country_txt )
# Out:
# [1970 1971 1972 1973 1974 1975 1976 1977 1978 1979 1980 1981 1986 1982
#  1983 1984 1985 1987 1988 1989 1990 1991 1992 1994 1995 1996 1997 1998
#  1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012
#  2013 2014 2015 2016 2017]
#
# ['Dominican Republic' 'Mexico' 'Philippines' 'Greece' 'Japan'
#  'United States' 'Uruguay' 'Italy' 'East Germany (GDR)' 'Ethiopia'
#  'Guatemala' 'Venezuela' 'West Germany (FRG)' 'Switzerland' 'Jordan'
#  'Spain' 'Brazil' 'Egypt' 'Argentina' 'Lebanon' 'Ireland' 'Turkey'
#  'Paraguay' 'Iran' 'United Kingdom' 'Colombia' 'Bolivia' 'Nicaragua'
#  'Netherlands' 'Belgium' 'Canada' 'Australia' 'Pakistan' 'Zambia' 'Sweden'
#  'Costa Rica' 'South Yemen' 'Cambodia' 'Israel' 'Poland' 'Taiwan' 'Panama'
#  'Kuwait' 'West Bank and Gaza Strip' 'Austria' 'Czechoslovakia' 'India'
#  'France' 'South Vietnam' 'Brunei' 'Zaire'
#  "People's Republic of the Congo" 'Portugal' 'Algeria' 'El Salvador'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Columns having missing values.
data.isnull().sum().sort_values(ascending = False)
# Out:
# gsubname3           181671
# weapsubtype4_txt    181621
# weapsubtype4        181621
# weaptype4           181618
# weaptype4_txt       181618
#                      ...
# suicide                  0
# success                  0
# crit3                    0
# property                 0
# eventid                  0
# Length: 135, dtype: int64

# %%
# Calculate the number of missing values for each column
missing_values = data.isnull().sum()
missing_values
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# top 10 attck types
attcktypes = data['attacktype1_txt'].value_counts().head(10)
attcktypes
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
# top 5 types of weapons used
weaptype = data['weaptype1_txt'].value_counts().head(10)
weaptype
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Name: weaptype1_txt, dtype: int64

# %%
# top 10 terrorists groups
gangname= data['gname'].value_counts().sort_values(ascending=False).head(10)
gangname
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: gname, dtype: int64

# %%
# target institutions by Terrorists
targettype= data['targtype1_txt'].value_counts().head()
targettype
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: targtype1_txt, dtype: int64

# %%
# counties affected the most
country_involved= data['natlty1_txt'].value_counts().head()
country_involved
# Out:
# Iraq           24113
# Pakistan       13900
# India          12098
# Afghanistan    10931
# Colombia        7922
# Name: natlty1_txt, dtype: int64

# %%
# years of attacks
year_of_attack= data['iyear'].value_counts().head(10)
year_of_attack
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# Name: iyear, dtype: int64

# %%
# Regions of attacks
region_of_attack= data['region_txt'].value_counts().head()
region_of_attack
# Out:
# Middle East & North Africa    50474
# South Asia                    44974
# South America                 18978
# Sub-Saharan Africa            17550
# Western Europe                16639
# Name: region_txt, dtype: int64

# %% [markdown]
# #### **What all manipulations have you done and insights you found?**

# %% [markdown]
# 1. There were many null values in columns of the dataset.
# 2. Most of the attacks type was Bombing/Explosion.
# 3. Top weapon type used was Explosives.
# 4. Most of the terrorists groups invovled were unknown.
# 5. Mostly Business, Local Citizens & property and
#    military were targeted.
# 6. El Salvador and United states were the top two most affected nations by Terrorism.
# 7. Most of the attcks were conducted in 1984.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ###**Chart 1 - Attacks by year**

# %%
# plot the bar graph
plt.figure(figsize=(15,8))
plt.bar(data['iyear'].value_counts().index, data['iyear'].value_counts().values)

#Set the X and Y labels
plt.xlabel("Year")
plt.ylabel("Frequency")
plt.title("Attacks by Year")

#showing the graph
plt.show()

# %% [markdown]
#  **1. Why did you pick the specific chart?**

# %% [markdown]
# 1.  Bar charts work well for showing data that changes
#     over time, like the number of attacks each year.
#
# 2. They make it easy to compare the number of attacks
#   across different years.
#
# 3. Bar charts are straightforward and
#   accessible to everyone.

# %% [markdown]
#  **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1.   We can see that from 1970 to 1992 there is upward trend in attacks
#
# 2.   From 1993 to 2004 we can see a downward trend in attacks
#
# 3.   And then from 2005 onwards we can see a upward trend in attacks with year 2014 having maximum number of attacks

# %% [markdown]
#  **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason**.

# %% [markdown]
# ##Positive Effects :
#
# **Spotting Trends:** We can see how the number of attacks changes over the years. If there are fewer attacks in recent years, it might mean that security has improved, which is good for business.
#
# **Resource Allocation:** We  can figure out which years had the most attacks. This helps us to use our resources better. If We do business in a place where there were more attacks in certain years, we can focus more on security during those years.
#
# **Market Opportunities:** If We see that attacks are going down, it might mean that the area is becoming more stable for business. This can create new business opportunities.
#
# ##Negative Growth Potential :
#
# **Economic Uncertainty:** If the graph shows more attacks happening each year, it might mean that the economy and politics are unstable. This can create uncertainty, reduce investments, and lower the confidence of consumers and investors.
#
# **Security Costs:** In some years with more attacks, we might need to spend more on security, which can be expensive for our business. This can increase our operational expenses and reduce our profits.
#
# **Reputation and Customer Perception:** If there are consistently more attacks in certain years, it can affect how people see the region or our business. It might discourage new customers and investors, leading to negative growth.

# %% [markdown]
# ###**Chart 2 - Attacks by months**

# %%
# giving size
plt.figure(figsize=(15,8))
#plotting countplot
sns.countplot(x=data.imonth,palette='colorblind')
#Set the X and Y labels
plt.xlabel("Months")
plt.ylabel("Number of Attacks")
# giving title
plt.title('Attacks by Month')
#showing plot
plt.show()

# %% [markdown]
#  **1. Why did you pick the specific chart?**

# %% [markdown]
# 1.  The countplot is the right choice because it effectively conveys the distribution of attacks across months in a clear and simple manner.
#
# 2. The data involves categories (months), making a countplot an ideal choice to display the distribution of attacks across the months.
#
# 3. It makes easy to compare the number of attacks in each month. The height of the bars provides a clear comparison.
#
# 4. Countplots are easy to understand and require minimal explanation, making them suitable for a wide audience.

# %% [markdown]
#  **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1.   Here we can see that most attacks took place in 5th month i.e. May
#
# 2.   Rest other months have total number of attacks between 12000 to 16000

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impacts:
#
# **Business Planning:** This information can help businesses plan better for security, sales, and operations, depending on the frequency of attacks in different months.
#
# **Resource Allocation:** It allows businesses to allocate resources more effectively to deal with security and operational challenges during specific months.
#
# ##Negative Growth Potential:
#
# **Operational Challenges:** During months with a higher number of attacks, businesses may face operational difficulties, which can increase costs and disrupt their operations, potentially affecting profits.
#
# **Reputation Risk:** Repeated attacks in certain months can harm a company's reputation, potentially leading to a decrease in customer trust and loyalty, which can impact business negatively.

# %% [markdown]
# ###**Chart 3 - Most attacked Days**

# %%
#plotting a bar graph
plt.figure(figsize=(15,8))# giving size
sns.barplot(x=data['iday'].value_counts().index , y=data['iday'].value_counts())
plt.xlabel("Days")#giving name to x axis
plt.ylabel("Number of Attacks")#giving name to y axis
plt.title('Attacks by Day')# giving title
plt.show()#showing plot

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Bar graphs are suitable for comparing different categories, in this case, the number of attacks on different days. Each bar represents a day, and the height of the bar shows how many attacks occurred on that day. It makes it easy to compare and understand the variations in attack frequencies across days.
#
# 2. Bar graphs work well when you have numerical data (in this case, the number of attacks) associated with different categories (days of the month).

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
#   1. First day 15th day of months are in which most attacks take place
#
#   2. The chart shows how often attacks occur on different days. It highlights which days witness more attacks and which have fewer incidents.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impacts:
#
# **Safer Planning:** Businesses can plan better for security and safety on days when attacks are more common, making operations safer for their employees and assets.
#
# **Resource Allocation:** They can use resources more effectively, making sure they're in the right place at the right time to respond to any incidents.
#
#
#
# ##Negative Growth Potential:
#
# **Operational Challenges:** On days with more attacks, businesses might face challenges like higher costs and possible disruptions, which can affect profits.
#
# **Reputation and Trust Issues:** If attacks happen on specific days, it can harm a company's reputation and make customers wary, which can lead to less business.

# %% [markdown]
# ###**Chart 4 - Most attacked Target**

# %%
#assigning most attacked target values to mat
mat=data['targtype1_txt'].value_counts().head()
mat
# Out:
# Private Citizens & Property    43511
# Military                       27984
# Police                         24506
# Government (General)           21283
# Business                       20669
# Name: targtype1_txt, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.bar(mat.index, mat.values)
plt.xlabel('Target Type')
plt.ylabel('Number of Attacks')
plt.title('Top 5 Most Attacked Target Types in Global Terrorism')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
#  **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. The choice of a line graph in the provided code may have been an error or oversight, as it is not the most suitable chart type for the data being visualized.
#
# 2. Line graphs are typically used for displaying trends over time or connecting data points in a sequence. In this case, the data represents the top 5 target types and their respective counts, making a line graph an unconventional choice.
#
# 3. To effectively represent the data and convey the frequencies of the top target types, a bar graph or a horizontal bar chart would be more appropriate and visually effective chart types.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. Civilians are the most target group to people accounting to 6461 by Groups followed by soldiers(3157) and Patrol(2942)

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impacts:
#
# **Market Opportunities:** Businesses can create products or services to meet the security needs of frequently targeted areas, potentially leading to more business.
#
# **Safety Measures:** Understanding common targets helps businesses improve security, protecting their assets and people, making operations safer and more stable.
#
# ##Negative Business Impacts:
#
# **Operational Challenges:** Businesses in frequently targeted sectors may face higher costs and disruptions, which can reduce their profits.
#
# **Reputation Risk:** Companies in commonly targeted areas may face a damaged reputation and trust issues, which can lead to negative growth.

# %% [markdown]
# ###**Chart 5 - Active Groups**

# %% [markdown]
# ####Let's find out which organizations have attacked the most and get some visuals of it

# %%
# Better to take frequency above 500 as we are considering data of 47 years.
active_group = gangname [1:11]
active_group
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: gname, dtype: int64

# %%
#create a bar graph
plt.figure(figsize=(8,5))
plt.barh(active_group.index, active_group.values,color="green")

#Set the X and Y labels
plt.title("10 most active Groups")
plt.xlabel("Groups")
plt.ylabel("Attacks conducted")

#showing the graph
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. A horizontal bar graph is an effective way to compare data values for different categories, in this case, the activity levels of various terrorist groups. It allows for a straightforward visual comparison of the number of attacks conducted by each group.
#
# 2. The chart is well-suited for showcasing the top 10 most active terrorist groups because it presents this information in a clear and concise manner.
#
# 3. A horizontal bar graph makes it easy for the viewer to identify the most active groups at a glance, as the longer bars represent higher activity levels.
#
# 4. The choice of a horizontal bar graph efficiently uses space and allows for the display of multiple groups with their corresponding attack counts.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. The chart shows the top 10 most active terrorist groups, making it easy to see which ones are the most active based on the number of attacks.
#
# 2. You can quickly compare the activity levels of these groups, with longer bars indicating more attacks.
#
# 3. This information is valuable for allocating resources effectively to address the activities of these highly active groups.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason**.

# %% [markdown]
# ##Positive Business Impact:
#
# **Enhanced Security:** The insights help businesses allocate resources and enhance security measures in regions where highly active terrorist groups are present. This can create a safer environment for business operations and positively impact safety and security.
#
# **Risk Mitigation:** By understanding which groups are most active, businesses can develop strategies to mitigate risks effectively, reducing the likelihood of disruptions due to terrorist activities.
#
# ##Negative Growth Potential:
#
# **Operational Challenges:** Operating in regions with highly active terrorist groups can pose operational challenges, potentially leading to disruptions and negatively impacting business growth.
#
# **Increased Costs:** The need for heightened security measures in such regions may result in higher security costs, which can affect profitability and potentially hinder growth.
#
# **Reputation and Investor Confidence:** The presence of highly active terrorist groups in areas where businesses operate can deter investors and customers, potentially leading to negative growth and damaging the reputation of the business.

# %% [markdown]
#  ### **Chart 6 - Number of terrorist activity by region each year**

# %%
terror_by_year_region = pd.crosstab(data.iyear, data.region_txt)

plt.figure(figsize=(12, 6))
sns.heatmap(terror_by_year_region, cmap='coolwarm', cbar=False)

plt.title('Terrorist Activities by Region in each Year')
plt.xlabel('Region')
plt.ylabel('Year')

plt.show()

# %% [markdown]
#  **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. The heatmap is effective for visualizing multidimensional data where two categorical variables (year and region) are being compared. It's a clear way to see patterns and relationships in such data.
#
# 2. Heatmaps use colors to represent values, making it easy to identify variations and trends in the data. Darker colors can represent higher values, and lighter colors can represent lower values, enhancing visual interpretation.
#
# 3. This chart is suitable for analyzing how terrorist activities are distributed across different regions over the years. It provides a clear overview of the changing patterns in terrorism by region.
#
# 4. Heatmaps efficiently use space to display data, making it easier to comprehend complex patterns in a limited visual area.
#
# 5. It's a user-friendly chart that allows viewers to quickly grasp trends and variations in terrorist activities by year and region without requiring in-depth data analysis.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. The chart helps us see how terrorist activities have changed over the years in different regions. Darker areas represent more activities, and lighter areas represent fewer activities.
#
# 2. Darker spots on the heatmap indicate regions where terrorism has been more prevalent over the years. This can help us identify areas that have experienced higher levels of conflict.
#
# 3. By looking at the rows (years), we can see how terrorism has evolved over time. It helps us understand whether the situation is getting better or worse in certain regions.
#
# 4. We can compare regions to see which ones have faced similar or different trends in terrorist activities, allowing for better analysis and understanding of the data.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impact:
#
# **Risk Assessment:** The insights can help businesses assess the risk associated with operating in specific regions. By understanding the historical patterns of terrorist activities in different regions, businesses can make more informed decisions about resource allocation and security measures.
#
# ##Negative Growth Potential:
#
# **Operational Challenges:** Regions with a consistent history of high terrorist activities may present operational challenges for businesses. This could include disruptions to supply chains, employee safety concerns, and difficulties in maintaining business operations.
#
# **Increased Costs:** Higher security and risk management costs may be incurred in regions with a history of terrorist activities. Businesses operating in these areas may need to allocate more resources to security measures, potentially impacting profitability.
#
# **Reputation and Investor Confidence:** Operating in regions with a history of terrorist activities could negatively affect a business's reputation and investor confidence. This might deter potential customers and investors, potentially leading to negative growth.

# %% [markdown]
# ###**Chart 7 - Attack Types Distribution**

# %%
attacktype = data['attacktype1_txt'].value_counts()[:7]
attacktype
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Unknown                            7276
# Unarmed Assault                    1015
# Name: attacktype1_txt, dtype: int64

# %%
plt.subplot(1,1,1)
attacktype.plot.pie(autopct='%1.1f%%', figsize=(7,7))
plt.title('Attack Type', fontweight="bold", size=22)
# Out:
# Text(0.5, 1.0, 'Attack Type')

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Pie charts are effective in displaying the '**Attack Type**' and contribute to a whole, emphasizing the relative sizes of each part.
#
# 2. When you want to compare the proportions of different categories, a pie chart can provide a visual representation of their relative magnitudes.
#
# 3.  Pie charts are visually intuitive and easy to interpret, making them accessible to a wide audience. They can quickly convey information without the need for complex numerical analysis.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. According to the chart, **Bombing/Explosion** is the most used attack type with arround 49% of the whole types of attacks.
#
# 2. Secondly, terrorist groups are using **Arms and Ammunition** to assult their targets of 24%.
#
# 3. Similarly, **Assassination** comes in 3rd category of attack which is 11%.
#
# 4. **Hostage(Kidnapping) and Facility / Infrastructure attack** are the attacked type which is arroung 6% respectivly.
#
# 5. Rest 10% of **other** attacked types performed by terrorist groups.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impact:
#
# **Safety Enhancement :** Understanding the most common attack types from the pie chart can help businesses improve their security measures and protect their employees and assets more effectively.
#
# ##Negative Growth Potential:
#
# **Risk Assessment :** Identifying the predominant attack types allows for better risk assessment. If specific attack types are prevalent, it may indicate higher risks, potentially leading to increased security costs and decreased investor and customer confidence.
#
# **Business Preparedness :** Recognizing the most frequent attack types helps businesses prepare for potential security challenges and instabilities, which can impact their operations and growth negatively.

# %% [markdown]
# ###**Chart 8 - Most Used Weapons by Terrorist Groups**

# %%
data.gname.value_counts()[0:15]
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Kurdistan Workers' Party (PKK)                       2310
# Basque Fatherland and Freedom (ETA)                  2024
# Communist Party of India - Maoist (CPI-Maoist)       1878
# Maoists                                              1630
# Liberation Tigers of Tamil Eelam (LTTE)              1606
# Name: gname, dtype: int64

# %%
plt.subplots(figsize=(15,7))
sns.barplot(x=data['weaptype1_txt'].value_counts()[:7].index,
            y=data['weaptype1_txt'].value_counts()[:7].values,
            palette="copper")
plt.title('Most Used Weapons')
plt.xlabel('Weapons Type')
plt.ylabel('No of Attacks')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Comparision among weapon used in types of attacks.
# 2. Identifing the number of attacks using each weapon type.
# 3. Can compare the number of attacks among all weapon type.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. In most of the attacks, **Explosives** are used widely.
# 2. **Fire Arms** are used less then **Explosives**.
# 3. **Chemical** and **Sabotage Equipments** are used in negligible numbers.

# %% [markdown]
#  **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impact:
#
# **Security Measures:** Knowing the most commonly used weapons in attacks helps businesses plan security measures, ensuring the safety of their employees and assets.
#
# ##Negative Growth Potential:
#
# **Risk Assessment:** Recognizing frequently used weapons indicates higher threat levels, potentially leading to increased security costs and reduced confidence from investors and customers.
#
# **Impact on Business Environment:** The prevalence of specific weapons can reflect the region's overall security and stability, affecting business growth and operations negatively

# %% [markdown]
# ###**Chart 9 - Number of Attacks by City**

# %%
plt.subplots(figsize=(17,6))
sns.barplot(x=data['city'].value_counts()[1:15].index,
            y=data['city'].value_counts()[1:15].values,
            palette="magma")

plt.title('Number of Attacks by City')
plt.xlabel('City')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. A bar chart is best for showing data categories like cities.
#
# 2. It's great for highlighting the top cities the most attacks.
#
# 3. Bar charts make it easy to compare attack counts between cities, providing a clear picture of the data.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. It identifies cities with the highest number of attacks,
#    highlighting potential terrorism hotspots.
#
# 2. The chart shows if attacks are concentrated in specific regions or
#    if they are evenly distributed.
#
# 3. Decision-makers can use the chart to prioritize cities that require
#    greater attention in terms of security and counter-terrorism efforts. This information is valuable for risk assessment and resource allocation.
#
# 4. Unusual spikes may indicate data quality issues or significant
#    events worth investigating.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impacts:
#
# **Security and Opportunity:** Businesses can make their operations safer in cities with more attacks and can offer safety solutions. This can create opportunities to provide security services and products.
#
# **Planning and Readiness:** Understanding attack numbers helps in making plans to keep operations running smoothly during disruptions, like attacks or crises.
#
# ##Negative Business Impacts:
#
# **Operational Challenges:** Operating in cities with more attacks can be harder. It might cost more, disrupt operations, and make it tough to find and keep employees.
#
# **Uncertainty:** These cities may not have stable economies, which can create uncertainty, slow growth, and make it harder to invest.
#
# **Reputation Risk:** Being in cities with attacks can harm a company's reputation and trust with customers, leading to negative growth.

# %% [markdown]
# ###**Chart 10 - Top 10 Victims Nationalities in Terrorist Attacks**

# %%
plt.subplots(figsize=(17,7))
sns.barplot(x= data['natlty1_txt'].value_counts()[:10].index,
            y= data['natlty1_txt'].value_counts()[:10].values,
            palette="viridis")
plt.title('Victims Nationality')
plt.xlabel('Victims Nationality')
plt.ylabel('No of Attacks')
plt.grid(False)
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Comparision among **Attackers Nationality and number of attacks**.
# 2. Identifing the number of attacks on the Targeted Nationalities.
# 3. Can compare the number of attacks among the countries

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **Iraq, pakistan and India's** people were among the most affected
#      by terrorism.
# 2. Almost **25000** people in Iraq, **14000** approx in pakistan and
#   **13000** for India.
# 3. Also **Afganistan, Colombia, Phillipines, Peru, El Salvador, United
#    States, and Turkey** are among the the **Top 10** countries in the world.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason**.

# %% [markdown]
# ##Positive Business Impact:
#
# **Market Insights :** The chart provides valuable information about the nationalities of victims in attacks. This data can help businesses understand the composition of the victim population in regions where they operate or plan to expand. It can be particularly useful for businesses that cater to specific nationalities, as it offers insights into target markets.
#
# **Risk Assessment:** By knowing the nationalities most affected by attacks, businesses can assess the safety of their operations in regions with a significant number of victims from specific countries. This information can guide security measures and risk management strategies.
#
# ##Negative Growth Potential:
#
# **Safety Concerns:** If the chart reveals that a specific nationality is consistently targeted or highly affected by attacks in a region, it may raise safety concerns. This can lead to a negative impact on businesses catering to customers from those nations, as it may deter potential customers or investors.
#
# **Diversity Consideration:** High victim counts from a single nationality may also indicate a lack of diversity in the region, which could potentially lead to instability and unrest. This lack of diversity can be a negative factor for business growth and investment.

# %% [markdown]
# #### **Chart 11 - Deaths per Year**

# %%
#making a dataframe dfx and assigning value of deaths per year in it
dfx=pd.DataFrame(data.groupby('iyear')['nkill'].sum()).reset_index()

# %%
#plotting a bar plot
plt.figure(figsize=(15, 6))
sns.barplot(data=dfx,x='iyear',y='nkill')
plt.title("Deaths Per Year")
plt.xlabel("Year")
plt.ylabel("Total Deaths")
plt.xticks(rotation=90)

plt.grid(False)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. The x-axis represents years, which is categorical data, making it appropriate for a bar plot. Each bar represents a specific year, and you can easily compare the number of deaths for different years.
#
# 2. The data is grouped by year, and the total number of deaths is calculated for each year. A bar plot is suitable for showing the summation of data for different categories.
#
# 3. Bar plots are great for comparing values across categories. In this case, you can quickly compare the number of deaths in different years, making it easy to identify trends and patterns.
#
# 4. Bar plots are easy to read and interpret. They provide a clear representation of the data, which is essential for effectively conveying information to an audience.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. We can see that there is a sharp rise in number of deaths after 2011 till year 2014 and after 2014 we can see decline in deaths

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason**.

# %% [markdown]
# ##Positive Business Impact:
#
# **Identifying Risk Areas:** Businesses operating in regions with a history of high terrorism-related deaths can use this information to assess and mitigate security risks. This knowledge can help them develop robust security measures, ensuring the safety of employees and assets.
#
# **Market Opportunities:** In regions where terrorism-related deaths are declining or stable, businesses may see improved stability and potential market opportunities. Increased stability can attract investment and business expansion.
#
# **Emergency Response Planning:** Insights from the chart can inform businesses about the potential need for emergency response plans and crisis management strategies, contributing to better preparedness in case of security threats.
#
# ##Negative Growth Potential:
#
# **Economic Contraction:** High levels of terrorism-related deaths can contribute to economic contraction and a decline in economic growth. This can affect businesses by reducing consumer spending, market demand, and overall business performance.
#
# **Investment Deterrence:** Regions with a history of increasing terrorism-related deaths may deter potential investors and hinder economic growth. This can result in a lack of investment in business expansion and development.
#
# **Market Volatility:** Increased terrorism-related deaths can lead to market volatility and uncertainty, affecting financial markets and investment portfolios, potentially resulting in negative returns for businesses with investments in affected regions.

# %% [markdown]
# ### **Chart 12 - Name of the countries that have been attacked by a large number of different terrorist organizations.**

# %%
# Grouping countries with organizations
group_country = data.groupby('country_txt')['gname'].nunique()
#.nunique() : it returns the number of unique elements in a pandas Series or DataFrame.

group_country.sort_values(ascending= False , inplace= True)

# taking top 10 countries
group_country_10 = group_country.head(10)

plt.plot(group_country_10,marker='*')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Number of Unique Organizations')
plt.title('Top 10 Countries with the Most Unique Terrorist Organizations')

plt.grid(False)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Line plots are typically used to show trends or changes in data over a continuous range (in this case, countries). In these case, we're visualizing the number of unique terrorist organizations, which can be considered a continuous variable.
#
# 2. The line plot effectively shows the ranking of the top 10 countries with the most unique terrorist organizations. It's easy to see the relative differences between these countries.
#
# 3. By using markers ('*'), we highlight individual data points for each country. This can make it easier to identify each country's value.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. We can see that India has been attacked by 301 different groups, United States has been attacked by 234 different group and then Italy which has been attacked by 223 different groups.
#
# 2. The chart clearly shows the countries with the highest number of unique terrorist organizations. It's easy to identify which countries are at the top of the list.
#
# 3. By observing the variations in the line plot, we can see that different countries have different numbers of unique terrorist organizations. Some countries have significantly more unique organizations than others.
#
# 4. The chart provides a ranking of the top 10 countries, allowing you to understand their relative positions in terms of the number of unique terrorist organizations. This ranking can be useful for further analysis or decision-making.
#
# 5. You can compare the number of unique terrorist organizations in these top 10 countries at a glance. This visual representation can be more intuitive than examining numbers in a table.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impacts:
#
# **New Markets:** The chart can help businesses find countries that need security services, opening up new business opportunities.
#
# **Expansion:** It can guide decisions on where to expand. Safer areas might be better for growing the business.
#
# **Risk Management:** Companies can use this information to plan for risks and protect their business in areas with more security concerns.
#
# ##Negative Business Impacts:
#
# **Challenges:** Operating in places with lots of security problems can be tough. There could be safety issues, higher costs, and difficulties finding and keeping good employees.
#
# **Economic Problems:** Areas with many security issues often have unstable economies, which can hurt business.

# %% [markdown]
# ### **Chart 13 - Distribution of Terrorist Activities by Region**

# %%
plt.figure (figsize = (15,7))
sns.countplot(data,x='region_txt',palette='plasma')
plt.title ('count of terrorist activities by region')
plt.xticks(rotation=90)
plt.grid(False)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
#   1. The data involves categorical information, specifically regions. A countplot is suitable for displaying the frequency or count of occurrences within each category.
#
#   2. A countplot is effective for comparing the number of terrorist activities across different regions. It provides a straightforward visual comparison of the counts.
#
#   3. Countplots are essentially bar charts, which are a common and intuitive choice for visualizing the distribution of categorical data. They are easy to understand and interpret.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. We can see which regions experience the most terrorist activities ,providing insights into geographical hotspots of terrorism
#
# 2. Different regions show varying levels of terrorist activity, indicating disparities in the distribution of incidents.
#
# 3. Some regions have a notably higher count of terrorist activities, suggesting they may be high-risk areas.

# %% [markdown]
# **3. Will the gained insights help creating a positive business impact?**
# **Are there any insights that lead to negative growth? Justify with specific reason**.

# %% [markdown]
# ##Positive Business Impacts:
#
# **Opportunities:** In some areas with more security concerns, businesses that provide safety and security services can find opportunities to help and make money.
#
# **Targeted Marketing:** Companies can sell products or services specifically designed for these areas, which can attract more customers.
#
# **Protecting Assets:** Businesses in high-risk areas can use this information to protect their stuff and employees, making their operations safer and more stable.
#
# ##Negative Business Impacts:
#
# **Challenges in Risky Areas:** Operating in places with lots of security problems can be tough, with extra costs, risks, and possible disruptions, which can hurt business profits.
#
# **Economic Uncertainty:** Areas with more security problems often have unstable economies, which can make business operations difficult, slow down growth, and make it hard to find investments.
#
# **Reputation and Trust Issues:** Companies in these areas can face trust problems if something goes wrong, which can harm their reputation and lead to customers not trusting them, resulting in negative growth.

# %% [markdown]
# ###**Chart - 14 - Correlation Heatmap**

# %%
# made new dataset for Correlation
corr_data1 = data[['iyear', 'country', 'nkill','nwound', 'region', 'attacktype1', 'targtype1', 'natlty1', 'weaptype1']]
list[corr_data1.columns]
# Out:
# list[Index(['iyear', 'country', 'nkill', 'nwound', 'region', 'attacktype1',
#        'targtype1', 'natlty1', 'weaptype1'],
#       dtype='object')]

# %%
corr_mat = corr_data1.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corr_mat,vmax=0.8,annot = True,fmt='.2f');

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Answer Here

# %% [markdown]
# ### **Chart - 15 - Pair Plot**

# %%
corr_data2 = data[['iyear', 'country_txt', 'nkill','nwound', 'region_txt', 'attacktype1', 'targtype1', 'natlty1', 'weaptype1']]
list[corr_data2.columns]
# Out:
# list[Index(['iyear', 'country_txt', 'nkill', 'nwound', 'region_txt', 'attacktype1',
#        'targtype1', 'natlty1', 'weaptype1'],
#       dtype='object')]

# %%
sns.pairplot(corr_data2)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Pair plots allow you to quickly visualize the relationships between variables. By examining the scatterplots, you can get a sense of whether variables are positively or negatively correlated or if there's any nonlinear relationship.
#
# 2. Pair plots help in identifying patterns or clusters in the data. If certain groups or clusters form in the scatterplots, it can indicate that the variables are related in a specific way.
#
# 3.  Pair plots can aid in variable selection by helping you identify which variables have a strong relationship with the target variable or with each other. This can be helpful in feature engineering or building predictive models.
#
# 4. Pair plots can also be used to detect anomalies or outliers in the data. Outliers may appear as points that deviate significantly from the general pattern in the scatterplots.1.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. By examining the scatterplot between the variables representing the number of attacks and the number of fatalities, we can observe if there is a correlation between the two.
#
# 2. If the dataset includes variables such as latitude and longitude, a pair plot can help visualize the spatial distribution of terrorist activities..
#
# 3.  Pair plots can reveal the relationship between different attack types (e.g., bombings, armed assaults) and the types of targets (e.g., private citizens, military, government).
#
# 4. If the dataset includes a temporal variable, such as the year or month of the attacks, a pair plot can show how the number of attacks or fatalities has changed over time.
#
# 5. Pair plots can be used to explore the relationship between the terrorist group responsible for an attack and various characteristics of the attack, such as the weapons used or the target type.
#
# 6. Pair plots can help detect outliers or unusual patterns in the data.

# %% [markdown]
# **3.Will the gained insights help creating a positive business impact?** **Are there any insights that lead to negative growth? Justify with specific reason.**

# %% [markdown]
# ##Positive Business Impacts:
#
# **Safer Operations:** By understanding which factors lead to more casualties, businesses can make their operations safer and protect their people and assets.
#
# **New Markets:** If certain attacks or weapons are linked to specific areas, businesses selling safety products or services can find new markets to offer their solutions.
#
# **Smarter Decisions:** Businesses can make better decisions based on these links. They can spend resources more wisely and keep their operations secure.
#
# ##Negative Business Impacts:
#
# **Riskier Areas:** If the analysis shows that some areas have more casualties, businesses operating there may face more risks and security challenges, which can hurt their operations and profits.
#
# **Resource Costs:** In places where certain factors are linked to higher casualties, businesses might have to spend more money on security. This can reduce their profits.
#
# **Economic Uncertainty:** Understanding these links can highlight regions with instability, which can create economic uncertainty. This might slow down business growth and profits.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### **What do you suggest the client to achieve Business Objective ?**

# %% [markdown]
# To achieve the business objective using the global terrorism dataset, it's important to understand the specific goals and requirements of the client. However, here are some general suggestions that can help leverage the dataset for various business objectives related to global terrorism:
#
# 1. **Trend analysis**: Conduct a comprehensive analysis of trends and patterns in global terrorism over time. This can involve examining the frequency, intensity, and geographical distribution of terrorist incidents, as well as identifying any shifts or changes in tactics, targets, or groups involved. Visualizations, such as time series plots and maps, can be helpful for presenting the findings.
#
# 2. **Identifying high-risk regions**: Analyze the dataset to identify regions or countries that are most affected by terrorism. This information can be used by businesses operating in those regions to assess security risks, make informed decisions about investments or expansions, and develop appropriate risk mitigation strategies.
#
# 3. **Risk assessment for supply chains and operations**: Utilize the dataset to assess the potential risks of terrorism along supply chains or operational networks. This can involve analyzing historical incidents to identify areas or routes with higher levels of risk. The insights gained can inform decision-making processes related to supply chain management, logistics, and security measures.
#
# 4. **Impact on the economy**: Investigate the economic impact of terrorism by analyzing its effects on specific sectors, regions, or countries. This analysis can help businesses understand how terrorism may affect their operations, investments, or markets. It can also provide insights into the effectiveness of counter-terrorism measures and policies.
#
# 5. **Identifying terrorist networks**: Utilize the dataset to identify and analyze the relationships and connections between different terrorist groups. Network analysis techniques can be employed to identify key actors, their affiliations, and their roles within the networks. This information can assist law enforcement agencies, intelligence organizations, or security companies in tracking and combating terrorism.
#
# 6. **Predictive modeling**: Develop predictive models using machine learning techniques to forecast future trends in global terrorism. These models can provide early warning systems or risk assessments to aid businesses in proactive decision-making and risk management.
#
# It's crucial to note that analyzing terrorism data requires sensitivity, ethical considerations, and domain expertise. It's advisable to consult with experts in the field and ensure that any analysis or conclusions drawn from the dataset are interpreted responsibly and in accordance with legal and ethical guidelines.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **The analysis of the global terrorism dataset provides valuable insights into the patterns and trends of terrorism incidents worldwide. By examining the data, several key conclusions can be drawn:**
#
#
# * The hot zone of terrorism till 2017, is Middle East & North Africa.
#
# * The country which has mostly faced the terror attacks is Iraq.
#
# * In the year 2014, the number of terror attacks are most.
#
# * The group Taliban has been behind the attacks more than other terrorists
#   groups.
#
# * Mostly Bombing/Explosion type attack has been chosen for the terrorism
#   acts.
#
# * Private Citizens & Property are mostly targetted following Militaries
#   and Police Forces.
#
# * Unclaimed attacks caused most of the casualties in terms of terror
#   attacks.
#
#
#
# 1. Most of the attacks were attacked through explosives and then through firearms.
# 2. Attacks were more during 2014 and then in 2015. When compared to attacks from 1970 onwards, the last 6 years scored a maximum. But from 2014 onwards count started decreasing.
# 3. Almost Every day has the same contribution but attacks were low during 31st and high during 15th and 1st.
# 4. Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.
# 5. The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.
# 6. For most of the attacks, the target is Private Citizens& property and the next Military leads.
# 7. Most of the attacks were through either Bombing or Explosion
#
# In conclusion, our analysis of the global terrorism dataset has unveiled significant patterns and trends in worldwide terrorism incidents. By examining the data, we've drawn several key conclusions that shed light on the complexities of terrorism on a global scale. These insights are essential for making informed decisions and policies to enhance global security and peace.

# %% [markdown]
# # ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
